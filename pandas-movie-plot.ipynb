# %%
import pandas as pd
movies = pd.read_csv('wiki_movie_plots_deduped.csv')

# %%
#1. How many records are in this dataset?

len(movies)
# Out:
# 34886

# %%
#2. What columns are in this DataFrame?

movies.columns
# Out:
# Index(['Release Year', 'Title', 'Origin/Ethnicity', 'Director', 'Cast',
#        'Genre', 'Wiki Page', 'Plot'],
#       dtype='object')

# %%
#3. How many columns are there?

movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34886 entries, 0 to 34885
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Release Year      34886 non-null  int64
#  1   Title             34886 non-null  object
#  2   Origin/Ethnicity  34886 non-null  object
#  3   Director          34886 non-null  object
#  4   Cast              33464 non-null  object
#  5   Genre             34886 non-null  object
#  6   Wiki Page         34886 non-null  object
#  7   Plot              34886 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 2.1+ MB

# %%
#4. How many non-null observations? 8 
#5. What are the last 8 records?

movies.tail(8)
# Out:
#        Release Year               Title Origin/Ethnicity  \
# 34878          2014    Mandıra Filozofu          Turkish
# 34879          2014        Winter Sleep          Turkish
# 34880          2014               Sivas          Turkish
# 34881          2014   The Water Diviner          Turkish
# 34882          2017  Çalgı Çengi İkimiz          Turkish
# 34883          2017        Olanlar Oldu          Turkish
# 34884          2017    Non-Transferable          Turkish
# 34885          2017  İstanbul Kırmızısı          Turkish
#
#                           Director  \
# 34878  Director: Müfit Can Saçıntı
# 34879  Director: Nuri Bilge Ceylan
# 34880       Director: Kaan Müjdeci
# 34881      Director: Russell Crowe
# 34882               Selçuk Aydemir
# 34883                  Hakan Algül
# 34884              Brendan Bradley
# 34885               Ferzan Özpetek
#
#                                                     Cast            Genre  \
# ...

# %%
#6. Use a function

length_to_exclude = len(movies) -8
movies.tail(-length_to_exclude)
# Out:
#        Release Year               Title Origin/Ethnicity  \
# 34878          2014    Mandıra Filozofu          Turkish
# 34879          2014        Winter Sleep          Turkish
# 34880          2014               Sivas          Turkish
# 34881          2014   The Water Diviner          Turkish
# 34882          2017  Çalgı Çengi İkimiz          Turkish
# 34883          2017        Olanlar Oldu          Turkish
# 34884          2017    Non-Transferable          Turkish
# 34885          2017  İstanbul Kırmızısı          Turkish
#
#                           Director  \
# 34878  Director: Müfit Can Saçıntı
# 34879  Director: Nuri Bilge Ceylan
# 34880       Director: Kaan Müjdeci
# 34881      Director: Russell Crowe
# 34882               Selçuk Aydemir
# 34883                  Hakan Algül
# 34884              Brendan Bradley
# 34885               Ferzan Özpetek
#
#                                                     Cast            Genre  \
# ...

# %%
#7. What are the first 5 records of the dataset? Use indexing.

movies.head(5)
# Out:
#    Release Year                             Title Origin/Ethnicity  \
# 0          1901            Kansas Saloon Smashers         American
# 1          1901     Love by the Light of the Moon         American
# 2          1901           The Martyred Presidents         American
# 3          1901  Terrible Teddy, the Grizzly King         American
# 4          1902            Jack and the Beanstalk         American
#
#                              Director Cast    Genre  \
# 0                             Unknown  NaN  unknown
# 1                             Unknown  NaN  unknown
# 2                             Unknown  NaN  unknown
# 3                             Unknown  NaN  unknown
# 4  George S. Fleming, Edwin S. Porter  NaN  unknown
#
#                                            Wiki Page  \
# 0  https://en.wikipedia.org/wiki/Kansas_Saloon_Sm...
# 1  https://en.wikipedia.org/wiki/Love_by_the_Ligh...
# 2  https://en.wikipedia.org/wiki/The_Martyred_Pre...
# ...

# %%
#8. What are the first 5 records of the dataset? Use a function.

length_excluded = len(movies) -5
movies.head(-length_excluded)
# Out:
#    Release Year                             Title Origin/Ethnicity  \
# 0          1901            Kansas Saloon Smashers         American
# 1          1901     Love by the Light of the Moon         American
# 2          1901           The Martyred Presidents         American
# 3          1901  Terrible Teddy, the Grizzly King         American
# 4          1902            Jack and the Beanstalk         American
#
#                              Director Cast    Genre  \
# 0                             Unknown  NaN  unknown
# 1                             Unknown  NaN  unknown
# 2                             Unknown  NaN  unknown
# 3                             Unknown  NaN  unknown
# 4  George S. Fleming, Edwin S. Porter  NaN  unknown
#
#                                            Wiki Page  \
# 0  https://en.wikipedia.org/wiki/Kansas_Saloon_Sm...
# 1  https://en.wikipedia.org/wiki/Love_by_the_Ligh...
# 2  https://en.wikipedia.org/wiki/The_Martyred_Pre...
# ...

# %%
#9. What are the top 5 listed genres?

movies.Genre.value_counts()
# Out:
# unknown                          6083
# drama                            5964
# comedy                           4379
# horror                           1167
# action                           1098
#                                  ...
# cbc-tv miniseries                   1
# bio-drama                           1
# national film board docudrama       1
# cult drama                          1
# horror romantic comedy              1
# Name: Genre, Length: 2265, dtype: int64

# %%
#10. Who are the top 5 directors?

movies.Director.value_counts()
# Out:
# Unknown                1124
# Michael Curtiz           79
# Hanna-Barbera            77
# Lloyd Bacon              66
# Jules White              63
#                        ...
# Brian Clemens             1
# Lester James Peries       1
# Maurice Hamblin           1
# Trevor Wrenn              1
# Ferzan Özpetek            1
# Name: Director, Length: 12593, dtype: int64

# %%
#What are the counts for origin/ethnicity?

movies['Origin/Ethinicity'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\.ipython\ANACONDA\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\.ipython\ANACONDA\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\.ipython\ANACONDA\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Origin/Ethinicity'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
#12. Are there any titles that are duplicated?

movies.Title.value_counts()
# Out:
# Cinderella               8
# The Three Musketeers     8
# Treasure Island          7
# Hero                     6
# Alice in Wonderland      6
#                         ..
# Leap of Faith            1
# A League of Their Own    1
# The Lawnmower Man        1
# Ladybugs                 1
# İstanbul Kırmızısı       1
# Name: Title, Length: 32432, dtype: int64

# %%
duplicatedRows = movies[movies.duplicated(['Title'])]
print(duplicatedRows)
# Out:
#        Release Year                    Title Origin/Ethnicity  \
# 27             1910        A Christmas Carol         American
# 55             1913  Dr. Jekyll and Mr. Hyde         American
# 85             1914             Laughing Gas         American
# 240            1918            The Squaw Man         American
# 286            1919   Nine-Tenths of the Law         American
# ...             ...                      ...              ...
# 34812          2017                Forgotten     South_Korean
# 34852          2010                    Honey          Turkish
# 34853          2010          Black and White          Turkish
# 34858          2010             The Crossing          Turkish
# 34871          2011           Merry-Go-Round          Turkish
#
#                               Director  \
# 27                    J. Searle Dawley
# 55     Herbert Brenon and Carl Laemmle
# 85                     Charlie Chaplin
# 240                   Cecil B. DeMille
# ...
